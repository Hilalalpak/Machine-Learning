# %% [markdown]
# <a href="https://www.kaggle.com/code/hilalalpak/flo-unsupervised-learning-technique?scriptVersionId=188591683" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="border-radius: 0 30px 0 20px; background-color:#2C3E50; padding:7px; margin-bottom: 10px;">
#         <p style="margin: 0; font-size: 20px; text-align: center; font-family: Roboto; font-weight: bold; letter-spacing: 2px; color:#ffffff"> UNSUPERVISED LEARNING CUSTOMER SEGMENTATION </p>
# </div>

# %% [markdown]
# <div style="text-align: center; margin-bottom: 10px;">
#     <div style="text-align: center; margin-bottom: 10px; padding-top: 10px; padding-bottom: 20px; background-image: url('https://t3.ftcdn.net/jpg/03/54/24/28/360_F_354242892_Nq43qDrKK9VKfGPvnBoBjiUEqP6AdEwq.jpg'); background-size: cover; border-radius: 8px; margin: 0 auto;">
#         <div style="text-align: left;">
#             <div style="background-image: url('https://www.flo.com.tr/pub/assets/flo-v2/images/flo-4-logo.png'); background-size: contain; background-repeat: no-repeat; background-position: center; width: 50px; height: 50px; border-radius: 8px; margin: 0 auto; background-color: #ffffff; overflow: hidden; background-clip: padding-box;"></div>
#             <div style="text-align: center;">
#             <blockquote style="border-left: 5px solid #2C3E50; padding-left: 10px; text-align: left;">
#                 <span style="font-weight: bold; font-size: 120%; font-family: Roboto; color: #2C3E50;">ABOUT DATASET: </span>
#                 <span style="color: #2C3E50; font-size: 120%; font-weight: bold; font-family: Roboto;">Flo Retailing, 2020 and 2021 years cover the behaviors of customers who shopped.
# </span>
#             </blockquote>
#             <div style="text-align: center;">
#                     <span style="font-weight: bold; font-size: 130%; font-family: Roboto; color: #2C3E50;">FEATURES: </span>
#                     <div style="margin-bottom: 10px; background-color: #232f3e; padding: 20px; width: fit-content; max-width: 700px; margin: auto; text-align: center; border-radius: 10px;">
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">master_id:</span> <span style="color: white;font-family: Roboto; ">Unique customer ID</span> <br>
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">last_order_channel:</span> <span style="color: white;font-family: Roboto; ">Last channel used for purchase</span> <br>
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">first_order_date:</span> <span style="color: white;font-family: Roboto; ">Date of customer's first purchase</span> <br>
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">last_order_date:</span> <span style="color: white;font-family: Roboto; ">Date of customer's last purchase</span> <br>
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">last_order_date_online:</span> <span style="color: white;font-family: Roboto; ">Date of customer's last online purchase</span> <br>
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">last_order_date_offline:</span> <span style="color: white;font-family: Roboto; ">Date of customer's last offline purchase</span> <br>
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">order_num_total_ever_online:</span> <span style="color: white;font-family: Roboto; ">Total number of purchases made online</span> <br>
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">order_num_total_ever_offline:</span> <span style="color: white;font-family: Roboto; ">Total number of purchases made offline</span> <br>
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">customer_value_total_ever_online:</span> <span style="color: white;font-family: Roboto; ">Total amount spent on online purchases</span> <br>
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">customer_value_total_ever_offline:</span> <span style="color: white;font-family: Roboto; ">Total amount spent on offline purchases</span> <br>
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">interested_in_categories_12:</span> <span style="color: white;font-family: Roboto; ">List of categories where customer made purchases in the last 12 months</span> <br>
#                         <span style="font-weight: bold; color: #FF5733;font-family: Roboto; ">order_channel:</span> <span style="color: white;font-family: Roboto; ">Channel used for the purchase (Android, iOS, Desktop, Mobile)</span> <br>
#                     </div>
#             </div>
#         </div>
#     </div>
# </div>

# %%
# Import Required Libraries

import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
from sklearn import metrics
print(sklearn.__version__)
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, cross_validate, StratifiedKFold, KFold, cross_val_predict
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler, RobustScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, make_scorer,  auc, classification_report
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsRegressor
from sklearn.impute import SimpleImputer, KNNImputer
from imblearn.over_sampling import SMOTE
from tqdm import tqdm
import scipy.stats as stats
from sklearn.datasets import make_blobs

# !pip install colored

### Design ###
from matplotlib import pyplot as plt
import missingno as msno
import plotly.graph_objects as go
import plotly.subplots as sp
import plotly.express as px
from tabulate import tabulate
from colored import fore, back, style
from yellowbrick.cluster import KElbowVisualizer
from scipy.cluster.hierarchy import dendrogram, linkage


import warnings
warnings.filterwarnings("ignore")

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Adjusting Row Column Settings

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.width', 500)
# Out:
# 1.2.2
# Collecting colored
#   Downloading colored-2.2.4-py3-none-any.whl.metadata (3.6 kB)
# Downloading colored-2.2.4-py3-none-any.whl (16 kB)
# Installing collected packages: colored
# Successfully installed colored-2.2.4

# %%
df = pd.read_csv("/kaggle/input/flo-dataset/flo_data_20k.csv")

# %% [markdown]
# <div style="text-align:center; font-size:26px; border: 2px solid #ffffff; border-radius: 5px; padding: 10px; margin-bottom: 10px; background-color:#2c4d80 ; font-family: Roboto ;  color: #ffffff;"> UNDERSTANDING THE DATASETs & PREPROCESSING
# </div>

# %%
df.head()
df.tail()
# Out:
#                               master_id order_channel last_order_channel first_order_date last_order_date last_order_date_online last_order_date_offline  order_num_total_ever_online  order_num_total_ever_offline  customer_value_total_ever_offline  customer_value_total_ever_online       interested_in_categories_12
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline       2020-10-30      2021-02-26             2021-02-21              2021-02-26                        4.000                         1.000                            139.990                           799.380                           [KADIN]
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile       2017-02-08      2021-02-16             2021-02-16              2020-01-10                       19.000                         2.000                            159.970                          1853.580  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App       2019-11-27      2020-11-27             2020-11-27              2019-12-01                        3.000                         2.000                            189.970                           395.350                    [ERKEK, KADIN]
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App       2021-01-06      2021-01-17             2021-01-17              2021-01-06                        1.000                         1.000                             39.990                            81.980               [AKTIFCOCUK, COCUK]
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop       2019-08-03      2021-03-07             2021-03-07              2019-08-03                        1.000                         1.000                             49.990                           159.990                       [AKTIFSPOR]
#                                   master_id order_channel last_order_channel first_order_date last_order_date last_order_date_online last_order_date_offline  order_num_total_ever_online  order_num_total_ever_offline  customer_value_total_ever_offline  customer_value_total_ever_online interested_in_categories_12
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f   Android App            Offline       2019-09-21      2020-07-05             2020-06-05              2020-07-05                        1.000                         2.000                            289.980                           111.980          [ERKEK, AKTIFSPOR]
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f       Desktop            Desktop       2020-03-01      2020-12-22             2020-12-22              2020-03-01                        1.000                         1.000                            150.480                           239.990                 [AKTIFSPOR]
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f       Ios App            Ios App       2019-09-11      2021-05-24             2021-05-24              2019-09-11                        2.000                         1.000                            139.980                           492.960                 [AKTIFSPOR]
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f   Android App        Android App       2019-03-27      2021-02-13             2021-02-13              2021-01-08                        1.000                         5.000                            711.790                           297.980          [ERKEK, AKTIFSPOR]
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f   Android App        Android App       2019-09-03      2020-06-06             2020-06-06              2019-09-03                        1.000                         1.000                             39.990                           221.980          [KADIN, AKTIFSPOR]

# %%
def check_df(dataframe, head=5):
    print("SHAPE".center(70,"-"))
    print(dataframe.shape)
    print("INFO".center(70,"-"))
    print(dataframe.info())
    print("MEMORY USAGE".center(70,"-"))
    print(f"{dataframe.memory_usage().sum() / (1024**2):.2f} MB")
    print("NUNIQUE".center(70,"-"))
    print(dataframe.nunique())
    print("MISSING VALUES".center(70,"-"))
    print(dataframe.isnull().sum())
    print("DUPLICATED VALUES".center(70,"-"))
    print(dataframe.duplicated().sum())
    
    
check_df(df)
# Out:
# --------------------------------SHAPE---------------------------------
# (19945, 12)
# ---------------------------------INFO---------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  object
#  4   last_order_date                    19945 non-null  object
#  5   last_order_date_online             19945 non-null  object
#  6   last_order_date_offline            19945 non-null  object
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
#  11  interested_in_categories_12        19945 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 1.8+ MB
# None
# -----------------------------MEMORY USAGE-----------------------------
# 1.83 MB
# -------------------------------NUNIQUE--------------------------------
# master_id                            19945
# order_channel                            4
# last_order_channel                       5
# first_order_date                      2465
# last_order_date                        366
# last_order_date_online                1743
# last_order_date_offline                738
# order_num_total_ever_online             57
# order_num_total_ever_offline            32
# customer_value_total_ever_offline     6097
# customer_value_total_ever_online     11292
# interested_in_categories_12             32
# dtype: int64
# ----------------------------MISSING VALUES----------------------------
# master_id                            0
# order_channel                        0
# last_order_channel                   0
# first_order_date                     0
# last_order_date                      0
# last_order_date_online               0
# last_order_date_offline              0
# order_num_total_ever_online          0
# order_num_total_ever_offline         0
# customer_value_total_ever_offline    0
# customer_value_total_ever_online     0
# interested_in_categories_12          0
# dtype: int64
# --------------------------DUPLICATED VALUES---------------------------
# 0

# %%
def grab_col_names(dataframe, cat_th=10, car_th=20):
    # cat_cols, cat_but_car
    cat_cols = [col for col in dataframe.columns if dataframe[col].dtypes == "O"]
    num_but_cat = [col for col in dataframe.columns if dataframe[col].nunique() < cat_th and
                   dataframe[col].dtypes != "O"]
    cat_but_car = [col for col in dataframe.columns if dataframe[col].nunique() > car_th and
                   dataframe[col].dtypes == "O"]
    cat_cols = cat_cols + num_but_cat
    cat_cols = [col for col in cat_cols if col not in cat_but_car]

    # num_cols
    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes != "O"]
    num_cols = [col for col in num_cols if col not in num_but_cat]

    print(f"Observations: {dataframe.shape[0]}")
    print(f"Variables: {dataframe.shape[1]}")
    print(f'cat_cols: {len(cat_cols)}')
    print(f'num_cols: {len(num_cols)}')
    print(f'cat_but_car: {len(cat_but_car)}')
    print(f'num_but_cat: {len(num_but_cat)}')
    
    return cat_cols, num_cols, num_but_cat, cat_but_car


cat_cols, num_cols, num_but_cat, cat_but_car = grab_col_names(df)
# Out:
# Observations: 19945
# Variables: 12
# cat_cols: 2
# num_cols: 4
# cat_but_car: 6
# num_but_cat: 0

# %%
percentiles = [0.10, 0.25, 0.30, 0.40, 0.60, 0.70, 0.80, 0.85, 0.90, 0.95, 0.99]
df.describe(percentiles=percentiles).T.style.background_gradient(axis=0, cmap='Oranges')
# Out:
# <style type="text/css">
# #T_75bf9_row0_col0, #T_75bf9_row0_col1, #T_75bf9_row0_col2, #T_75bf9_row0_col3, #T_75bf9_row0_col4, #T_75bf9_row0_col5, #T_75bf9_row0_col6, #T_75bf9_row0_col7, #T_75bf9_row0_col8, #T_75bf9_row0_col9, #T_75bf9_row0_col10, #T_75bf9_row0_col11, #T_75bf9_row0_col12, #T_75bf9_row0_col13, #T_75bf9_row0_col14, #T_75bf9_row0_col16, #T_75bf9_row1_col0, #T_75bf9_row1_col1, #T_75bf9_row1_col2, #T_75bf9_row1_col3, #T_75bf9_row1_col4, #T_75bf9_row1_col5, #T_75bf9_row1_col6, #T_75bf9_row1_col7, #T_75bf9_row1_col8, #T_75bf9_row1_col9, #T_75bf9_row1_col10, #T_75bf9_row1_col11, #T_75bf9_row1_col12, #T_75bf9_row1_col13, #T_75bf9_row1_col14, #T_75bf9_row1_col15, #T_75bf9_row1_col16, #T_75bf9_row2_col0, #T_75bf9_row3_col0 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_75bf9_row0_col15 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_75bf9_row2_col1 {
#   background-color: #fc8a39;
#   color: #f1f1f1;
# }
# #T_75bf9_row2_col2 {
#   background-color: #fdb271;
#   color: #000000;
# }
# #T_75bf9_row2_col3 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_75bf9_row2_col4 {
#   background-color: #e25508;
#   color: #f1f1f1;
# }
# #T_75bf9_row2_col5 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_75bf9_row2_col6, #T_75bf9_row2_col7 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_75bf9_row2_col8 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_75bf9_row2_col9 {
#   background-color: #f4721e;
#   color: #f1f1f1;
# }
# #T_75bf9_row2_col10 {
#   background-color: #f67824;
#   color: #f1f1f1;
# }
# #T_75bf9_row2_col11 {
#   background-color: #fb8634;
#   color: #f1f1f1;
# }
# #T_75bf9_row2_col12 {
#   background-color: #fc8b3a;
#   color: #f1f1f1;
# }
# #T_75bf9_row2_col13 {
#   background-color: #fd9344;
#   color: #000000;
# }
# #T_75bf9_row2_col14 {
#   background-color: #fd9c51;
#   color: #000000;
# }
# #T_75bf9_row2_col15 {
#   background-color: #fdac67;
#   color: #000000;
# }
# #T_75bf9_row2_col16 {
#   background-color: #fda762;
#   color: #000000;
# }
# #T_75bf9_row3_col1, #T_75bf9_row3_col2, #T_75bf9_row3_col3, #T_75bf9_row3_col4, #T_75bf9_row3_col5, #T_75bf9_row3_col6, #T_75bf9_row3_col7, #T_75bf9_row3_col8, #T_75bf9_row3_col9, #T_75bf9_row3_col10, #T_75bf9_row3_col11, #T_75bf9_row3_col12, #T_75bf9_row3_col13, #T_75bf9_row3_col14, #T_75bf9_row3_col15, #T_75bf9_row3_col16 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_75bf9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75bf9_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_75bf9_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_75bf9_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_75bf9_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_75bf9_level0_col4" class="col_heading level0 col4" >10%</th>
#       <th id="T_75bf9_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_75bf9_level0_col6" class="col_heading level0 col6" >30%</th>
#       <th id="T_75bf9_level0_col7" class="col_heading level0 col7" >40%</th>
#       <th id="T_75bf9_level0_col8" class="col_heading level0 col8" >50%</th>
#       <th id="T_75bf9_level0_col9" class="col_heading level0 col9" >60%</th>
#       <th id="T_75bf9_level0_col10" class="col_heading level0 col10" >70%</th>
#       <th id="T_75bf9_level0_col11" class="col_heading level0 col11" >80%</th>
#       <th id="T_75bf9_level0_col12" class="col_heading level0 col12" >85%</th>
#       <th id="T_75bf9_level0_col13" class="col_heading level0 col13" >90%</th>
#       <th id="T_75bf9_level0_col14" class="col_heading level0 col14" >95%</th>
#       <th id="T_75bf9_level0_col15" class="col_heading level0 col15" >99%</th>
#       <th id="T_75bf9_level0_col16" class="col_heading level0 col16" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75bf9_level0_row0" class="row_heading level0 row0" >order_num_total_ever_online</th>
#       <td id="T_75bf9_row0_col0" class="data row0 col0" >19945.000000</td>
#       <td id="T_75bf9_row0_col1" class="data row0 col1" >3.110855</td>
#       <td id="T_75bf9_row0_col2" class="data row0 col2" >4.225647</td>
#       <td id="T_75bf9_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_75bf9_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_75bf9_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_75bf9_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_75bf9_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_75bf9_row0_col8" class="data row0 col8" >2.000000</td>
#       <td id="T_75bf9_row0_col9" class="data row0 col9" >2.000000</td>
#       <td id="T_75bf9_row0_col10" class="data row0 col10" >3.000000</td>
#       <td id="T_75bf9_row0_col11" class="data row0 col11" >4.000000</td>
#       <td id="T_75bf9_row0_col12" class="data row0 col12" >5.000000</td>
#       <td id="T_75bf9_row0_col13" class="data row0 col13" >7.000000</td>
#       <td id="T_75bf9_row0_col14" class="data row0 col14" >10.000000</td>
#       <td id="T_75bf9_row0_col15" class="data row0 col15" >20.000000</td>
#       <td id="T_75bf9_row0_col16" class="data row0 col16" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75bf9_level0_row1" class="row_heading level0 row1" >order_num_total_ever_offline</th>
#       <td id="T_75bf9_row1_col0" class="data row1 col0" >19945.000000</td>
#       <td id="T_75bf9_row1_col1" class="data row1 col1" >1.913913</td>
#       <td id="T_75bf9_row1_col2" class="data row1 col2" >2.062880</td>
#       <td id="T_75bf9_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_75bf9_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_75bf9_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_75bf9_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_75bf9_row1_col7" class="data row1 col7" >1.000000</td>
#       <td id="T_75bf9_row1_col8" class="data row1 col8" >1.000000</td>
#       <td id="T_75bf9_row1_col9" class="data row1 col9" >2.000000</td>
#       <td id="T_75bf9_row1_col10" class="data row1 col10" >2.000000</td>
#       <td id="T_75bf9_row1_col11" class="data row1 col11" >3.000000</td>
#       <td id="T_75bf9_row1_col12" class="data row1 col12" >3.000000</td>
#       <td id="T_75bf9_row1_col13" class="data row1 col13" >4.000000</td>
#       <td id="T_75bf9_row1_col14" class="data row1 col14" >4.000000</td>
#       <td id="T_75bf9_row1_col15" class="data row1 col15" >7.000000</td>
#       <td id="T_75bf9_row1_col16" class="data row1 col16" >109.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75bf9_level0_row2" class="row_heading level0 row2" >customer_value_total_ever_offline</th>
#       <td id="T_75bf9_row2_col0" class="data row2 col0" >19945.000000</td>
#       <td id="T_75bf9_row2_col1" class="data row2 col1" >253.922597</td>
#       <td id="T_75bf9_row2_col2" class="data row2 col2" >301.532853</td>
#       <td id="T_75bf9_row2_col3" class="data row2 col3" >10.000000</td>
#       <td id="T_75bf9_row2_col4" class="data row2 col4" >59.990000</td>
#       <td id="T_75bf9_row2_col5" class="data row2 col5" >99.990000</td>
#       <td id="T_75bf9_row2_col6" class="data row2 col6" >110.480000</td>
#       <td id="T_75bf9_row2_col7" class="data row2 col7" >140.230000</td>
#       <td id="T_75bf9_row2_col8" class="data row2 col8" >179.980000</td>
#       <td id="T_75bf9_row2_col9" class="data row2 col9" >220.860000</td>
#       <td id="T_75bf9_row2_col10" class="data row2 col10" >281.868000</td>
#       <td id="T_75bf9_row2_col11" class="data row2 col11" >365.058000</td>
#       <td id="T_75bf9_row2_col12" class="data row2 col12" >429.896000</td>
#       <td id="T_75bf9_row2_col13" class="data row2 col13" >519.950000</td>
#       <td id="T_75bf9_row2_col14" class="data row2 col14" >694.222000</td>
#       <td id="T_75bf9_row2_col15" class="data row2 col15" >1219.946800</td>
#       <td id="T_75bf9_row2_col16" class="data row2 col16" >18119.140000</td>
#     </tr>
#     <tr>
#       <th id="T_75bf9_level0_row3" class="row_heading level0 row3" >customer_value_total_ever_online</th>
#       <td id="T_75bf9_row3_col0" class="dat

# %% [markdown]
# <div style="background-color:#A9B6D2; border-radius: 10px; padding: 10px; margin-bottom: 20px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#         <p style="margin: 10px 0 0 0; font-size: 22px; font-weight: Bold; font-family: Roboto; color: #1F2A44; text-align: center;">🔎 Observations</p>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">Some variables contain date information, and set their data type to datetime.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">Variables that appear categorical but are actually cardinal (numeric) will not be modified because they typically serve the purpose of ranking or defining ranges, and are used categorically.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">Identified outliers in analysis, and either suppress them or exclude them from calculations.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">To ensure consistent results, we will change the analysis date to two days after the last purchase date.</p>
#     </div>
# </div>

# %%
## Datetime
date_columns = df.columns[df.columns.str.contains("date")]
df[date_columns] = df[date_columns].apply(lambda x: pd.to_datetime(x, dayfirst=True))

# %%
## refrain
cat_cols, num_cols, num_but_cat, cat_but_car = grab_col_names(df)
# Out:
# Observations: 19945
# Variables: 12
# cat_cols: 2
# num_cols: 8
# cat_but_car: 2
# num_but_cat: 0

# %%
import datetime as dt

df["last_order_date"].max()  # Assuming this returns '2021-05-30'
today_date = dt.datetime(2021, 6, 1)  # Setting the analysis date two days after the last purchase date
# Out:
# Timestamp('2021-05-30 00:00:00')

# %% [markdown]
# <div style="text-align:center; font-size:26px; border: 2px solid #ffffff; border-radius: 5px; padding: 10px; margin-bottom: 10px; background-color:#2c4d80 ; font-family: Roboto ;  color: #ffffff;"> VISUALIZATION
# </div>

# %%
df[num_cols].corr()
# Out:
#                                    first_order_date  last_order_date  last_order_date_online  last_order_date_offline  order_num_total_ever_online  order_num_total_ever_offline  customer_value_total_ever_offline  customer_value_total_ever_online
# first_order_date                              1.000            0.111                   0.492                    0.028                       -0.355                        -0.080                             -0.044                            -0.197
# last_order_date                               0.111            1.000                   0.344                    0.195                        0.105                         0.045                              0.065                             0.107
# last_order_date_online                        0.492            0.344                   1.000                   -0.318                        0.136                        -0.052                             -0.073                             0.150
# last_order_date_offline                       0.028            0.195                  -0.318                    1.000                       -0.076                         0.213                              0.270                            -0.069
# order_num_total_ever_online                  -0.355            0.105                   0.136                   -0.076                        1.000                         0.022                              0.003                             0.816
# order_num_total_ever_offline                 -0.080            0.045                  -0.052                    0.213                        0.022                         1.000                              0.691                             0.011
# customer_value_total_ever_offline            -0.044            0.065                  -0.073                    0.270                        0.003                         0.691                              1.000                             0.035
# customer_value_total_ever_online             -0.197            0.107                   0.150                   -0.069                        0.816                         0.011                              0.035                             1.000

# %%
# Calculate corr matrix
corr_matrix = df[num_cols].corr()

# Create Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap=sns.diverging_palette(30, 220, as_cmap=True), fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show();

# %% [markdown]
# <div style="background-color:#FFB347; border-radius: 10px; padding: 10px; margin-bottom: 20px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#         <p style="margin: 10px 0 0 0; font-size: 22px; font-weight: Bold; font-family: Roboto; color: #1F2A44; text-align: center;">📝  Comments</p>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 16px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">According to the data analysis, a significant relationship between 'order_num_total_ever_online' and 'customer_value_total_ever_online' indicates a positive correlation between online purchases and total customer value.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 16px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">Similarly, the connection observed between 'order_num_total_ever_offline' and 'customer_value_total_ever_offline' highlights a strong relationship between offline purchases and total customer value. These findings underscore the impact of omnichannel strategies in retail.</p>
#     </div>
# </div>

# %%
def plot_boxplot_per_variable(dataframe):
    numeric_cols = dataframe.select_dtypes(include=['int64', 'float64']).columns
    num_plots = len(numeric_cols)
    num_cols = 2
    num_rows = (num_plots + num_cols - 1) // num_cols
    
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(18, num_rows * 6))
    axes = axes.flatten()
    
    boxprops = dict(linewidth=2, color='#333333') 
    whiskerprops = dict(linewidth=2, color='#333333')  
    capprops = dict(linewidth=2, color='#333333')  
    medianprops = dict(linewidth=2, color='r') 

    for i, col in enumerate(numeric_cols):
        sns.boxplot(y=dataframe[col], ax=axes[i], orient='h', boxprops=boxprops, whiskerprops=whiskerprops,
                    capprops=capprops, medianprops=medianprops) 
        axes[i].set_title(f'Box Plot of {col}', fontsize=14, fontweight='bold') 
        axes[i].set_xlabel('Value', fontsize=12)  
        axes[i].set_ylabel(col, fontsize=12, fontweight='bold') 
        axes[i].tick_params(axis='both', labelsize=10)  
        axes[i].grid(True, linestyle='--', linewidth=0.5, color='lightgray')  
    
    for j in range(num_plots, len(axes)):
        axes[j].axis('off')
    
    plt.tight_layout(pad=2.0) 
    plt.show()
    

# Call the function with the filtered columns
plot_boxplot_per_variable(df[num_cols])

# %%
plt.figure(figsize=(16, 12))

# Box plot for order_num_total_ever_online by order_channel
plt.subplot(2, 2, 1)
sns.boxplot(x='order_channel', y='order_num_total_ever_online', data=df,
            whiskerprops=dict(linestyle='-', linewidth=1.5, color='black'),
            flierprops=dict(marker='o', markersize=6, markerfacecolor='red', markeredgecolor='black'))
plt.title('Box Plot of Order Number (Online) by Order Channel')
plt.xlabel('Order Channel')
plt.ylabel('Order Number (Online)')

# Box plot for customer_value_total_ever_online by order_channel
plt.subplot(2, 2, 2)
sns.boxplot(x='order_channel', y='customer_value_total_ever_online', data=df,
            whiskerprops=dict(linestyle='-', linewidth=1.5, color='black'),
            flierprops=dict(marker='o', markersize=6, markerfacecolor='red', markeredgecolor='black'))
plt.title('Box Plot of Customer Value (Online) by Order Channel')
plt.xlabel('Order Channel')
plt.ylabel('Customer Value (Online)')

# Box plot for order_num_total_ever_online by last_order_channel
plt.subplot(2, 2, 3)
sns.boxplot(x='last_order_channel', y='order_num_total_ever_online', data=df,
            whiskerprops=dict(linestyle='-', linewidth=1.5, color='black'),
            flierprops=dict(marker='o', markersize=6, markerfacecolor='red', markeredgecolor='black'))
plt.title('Box Plot of Order Number (Online) by Last Order Channel')
plt.xlabel('Last Order Channel')
plt.ylabel('Order Number (Online)')

# Box plot for customer_value_total_ever_online by last_order_channel
plt.subplot(2, 2, 4)
sns.boxplot(x='last_order_channel', y='customer_value_total_ever_online', data=df,
            whiskerprops=dict(linestyle='-', linewidth=1.5, color='black'),
            flierprops=dict(marker='o', markersize=6, markerfacecolor='red', markeredgecolor='black'))
plt.title('Box Plot of Customer Value (Online) by Last Order Channel')
plt.xlabel('Last Order Channel')
plt.ylabel('Customer Value (Online)')

plt.tight_layout()
plt.show();

# %% [markdown]
# <div style="background-color:#FFDAB9; border-radius: 10px; padding: 10px; margin-bottom: 20px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 16px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">Excessive outliers can adversely affect statistical analyses and model performance. To ensure more reliable results from the model, outlier suppression will be implemented in future steps.</p>
#     </div>
# </div>

# %%
# daily order count over time
daily_orders = df.groupby(df['first_order_date'].dt.date)['master_id'].count()

plt.figure(figsize=(12, 6))
plt.plot(daily_orders.index, daily_orders.values, marker='o', linestyle='-')
plt.title('Daily Order Count Time Series')
plt.xlabel('Date')
plt.ylabel('Order Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show();

# %% [markdown]
# <div style="background-color:#FFDAB9; border-radius: 10px; padding: 10px; margin-bottom: 20px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 16px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">The analysis of daily purchases reveals a notable increase between 2019 and 2020. Particularly during the summer months, sales volume remains consistently high. However, a declining trend is observed between 2020 and 2021.</p>
#     </div>
# </div>

# %%
# monthly total online and offline orders
monthly_online_orders = df.groupby(df['last_order_date_online'].dt.to_period('M'))['order_num_total_ever_online'].sum()
monthly_offline_orders = df.groupby(df['last_order_date_offline'].dt.to_period('M'))['order_num_total_ever_offline'].sum()

# The first date of offline order records
monthly_online_orders = monthly_online_orders['2019-01':]
monthly_offline_orders = monthly_offline_orders['2019-01':]

plt.figure(figsize=(12, 6))
plt.plot(monthly_online_orders.index.strftime('%Y-%m'), monthly_online_orders.values, marker='o', linestyle='-', label='Online Orders')
plt.plot(monthly_offline_orders.index.strftime('%Y-%m'), monthly_offline_orders.values, marker='o', linestyle='-', label='Offline Orders')
plt.title('Monthly Online and Offline Order Count Time Series')
plt.xlabel('Month')
plt.ylabel('Order Count')
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show();

# %% [markdown]
# <div style="background-color:#FFDAB9; border-radius: 10px; padding: 10px; margin-bottom: 20px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 16px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">Sales show an increasing trend year over year. However, when we analyze each year individually, we observe relatively higher sales during the summer months.</p>
#     </div>
# </div>

# %%
category_counts = df['interested_in_categories_12'].value_counts()

labels = category_counts.index
values = category_counts.values

fig = go.Figure(data=[go.Pie(labels=labels, values=values, textinfo='percent', hole=0.3)])

fig.update_layout(title='Distribution of Interested Categories',
                  showlegend=True,
                  width=1000,
                  height=800)

fig.show();
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="679352a9-2490-4718-80f0-018dd86afa9b" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("679352a9-2490-4718-80f0-018dd86afa9b")) {                    Plotly.newPlot(                        "679352a9-2490-4718-80f0-018dd86afa9b",                        [{"hole":0.3,"labels":["[AKTIFSPOR]","[KADIN]","[]","[ERKEK]","[KADIN, AKTIFSPOR]","[ERKEK, AKTIFSPOR]","[ERKEK, KADIN]","[COCUK]","[ERKEK, KADIN, AKTIFSPOR]","[AKTIFCOCUK]","[COCUK, KADIN]","[AKTIFCOCUK, COCUK]","[AKTIFCOCUK, AKTIFSPOR]","[COCUK, AKTIFSPOR]","[COCUK, KADIN, AKTIFSPOR]","[AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]","[ERKEK, COCUK]","[ERKEK, COCUK, KADIN, AKTIFSPOR]","[AKTIFCOCUK, COCUK, KADIN]","[AKTIFCOCUK, KADIN]","[ERKEK, COCUK, KADIN]","[AKTIFCOCUK, COCUK, KADIN, AKTIFSPOR]","[AKTIFCOCUK, COCUK, AKTIFSPOR]","[AKTIFCOCUK, KADIN, AKTIFSPOR]","[ERKEK, COCUK, AKTIFSPOR]","[AKTIFCOCUK, ERKEK]","[AKTIFCOCUK, ERKEK, AKTIFSPOR]","[AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]","[AKTIFCOCUK, ERKEK, COCUK]","[AKTIFCOCUK, ERKEK, COCUK, KADIN]","[AKTIFCOCUK, ERKEK, COCUK, AKTIFSPOR]","[AKTIFCOCUK, ERKEK, KADIN]"],"textinfo":"percent","values":[3464,2158,2135,1973,1352,1178,848,836,775,679,443,349,317,317,241,223,215,213,213,210,204,203,202,184,156,152,142,132,122,115,105,89],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":" ...

# %% [markdown]
# <div style="text-align:center; font-size:26px; border: 2px solid #ffffff; border-radius: 5px; padding: 10px; margin-bottom: 10px; background-color:#2c4d80 ; font-family: Roboto ;  color: #ffffff;"> OUTLIER ANALYSIS
# </div>

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols] = df[numeric_cols].apply(lambda x: np.log1p(x))

# %%
percentiles = [0.10, 0.25, 0.30, 0.40, 0.60, 0.70, 0.80, 0.85, 0.90, 0.95, 0.99]
df[numeric_cols].describe(percentiles=percentiles).T.style.background_gradient(axis=0, cmap='Oranges')
# Out:
# <style type="text/css">
# #T_2ed88_row0_col0, #T_2ed88_row0_col3, #T_2ed88_row0_col4, #T_2ed88_row0_col5, #T_2ed88_row0_col6, #T_2ed88_row0_col7, #T_2ed88_row0_col9, #T_2ed88_row1_col0, #T_2ed88_row1_col1, #T_2ed88_row1_col2, #T_2ed88_row1_col3, #T_2ed88_row1_col4, #T_2ed88_row1_col5, #T_2ed88_row1_col6, #T_2ed88_row1_col7, #T_2ed88_row1_col8, #T_2ed88_row1_col9, #T_2ed88_row1_col10, #T_2ed88_row1_col11, #T_2ed88_row1_col12, #T_2ed88_row1_col13, #T_2ed88_row1_col14, #T_2ed88_row1_col15, #T_2ed88_row1_col16, #T_2ed88_row2_col0, #T_2ed88_row3_col0 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_2ed88_row0_col1, #T_2ed88_row0_col11 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# #T_2ed88_row0_col2 {
#   background-color: #fdb576;
#   color: #000000;
# }
# #T_2ed88_row0_col8 {
#   background-color: #feecd9;
#   color: #000000;
# }
# #T_2ed88_row0_col10 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_2ed88_row0_col12 {
#   background-color: #feecda;
#   color: #000000;
# }
# #T_2ed88_row0_col13 {
#   background-color: #feebd7;
#   color: #000000;
# }
# #T_2ed88_row0_col14 {
#   background-color: #fee4ca;
#   color: #000000;
# }
# #T_2ed88_row0_col15 {
#   background-color: #fee0c1;
#   color: #000000;
# }
# #T_2ed88_row0_col16 {
#   background-color: #fee9d4;
#   color: #000000;
# }
# #T_2ed88_row2_col1 {
#   background-color: #a13403;
#   color: #f1f1f1;
# }
# #T_2ed88_row2_col2 {
#   background-color: #c64102;
#   color: #f1f1f1;
# }
# #T_2ed88_row2_col3, #T_2ed88_row2_col11 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_2ed88_row2_col4, #T_2ed88_row2_col5, #T_2ed88_row2_col8 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_2ed88_row2_col6 {
#   background-color: #9e3303;
#   color: #f1f1f1;
# }
# #T_2ed88_row2_col7 {
#   background-color: #9c3203;
#   color: #f1f1f1;
# }
# #T_2ed88_row2_col9, #T_2ed88_row2_col10 {
#   background-color: #a03403;
#   color: #f1f1f1;
# }
# #T_2ed88_row2_col12 {
#   background-color: #a63603;
#   color: #f1f1f1;
# }
# #T_2ed88_row2_col13 {
#   background-color: #a93703;
#   color: #f1f1f1;
# }
# #T_2ed88_row2_col14 {
#   background-color: #ab3803;
#   color: #f1f1f1;
# }
# #T_2ed88_row2_col15 {
#   background-color: #b33b02;
#   color: #f1f1f1;
# }
# #T_2ed88_row2_col16 {
#   background-color: #b03903;
#   color: #f1f1f1;
# }
# #T_2ed88_row3_col1, #T_2ed88_row3_col2, #T_2ed88_row3_col3, #T_2ed88_row3_col4, #T_2ed88_row3_col5, #T_2ed88_row3_col6, #T_2ed88_row3_col7, #T_2ed88_row3_col8, #T_2ed88_row3_col9, #T_2ed88_row3_col10, #T_2ed88_row3_col11, #T_2ed88_row3_col12, #T_2ed88_row3_col13, #T_2ed88_row3_col14, #T_2ed88_row3_col15, #T_2ed88_row3_col16 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2ed88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ed88_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_2ed88_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_2ed88_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_2ed88_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_2ed88_level0_col4" class="col_heading level0 col4" >10%</th>
#       <th id="T_2ed88_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_2ed88_level0_col6" class="col_heading level0 col6" >30%</th>
#       <th id="T_2ed88_level0_col7" class="col_heading level0 col7" >40%</th>
#       <th id="T_2ed88_level0_col8" class="col_heading level0 col8" >50%</th>
#       <th id="T_2ed88_level0_col9" class="col_heading level0 col9" >60%</th>
#       <th id="T_2ed88_level0_col10" class="col_heading level0 col10" >70%</th>
#       <th id="T_2ed88_level0_col11" class="col_heading level0 col11" >80%</th>
#       <th id="T_2ed88_level0_col12" class="col_heading level0 col12" >85%</th>
#       <th id="T_2ed88_level0_col13" class="col_heading level0 col13" >90%</th>
#       <th id="T_2ed88_level0_col14" class="col_heading level0 col14" >95%</th>
#       <th id="T_2ed88_level0_col15" class="col_heading level0 col15" >99%</th>
#       <th id="T_2ed88_level0_col16" class="col_heading level0 col16" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ed88_level0_row0" class="row_heading level0 row0" >order_num_total_ever_online</th>
#       <td id="T_2ed88_row0_col0" class="data row0 col0" >19945.000000</td>
#       <td id="T_2ed88_row0_col1" class="data row0 col1" >1.192774</td>
#       <td id="T_2ed88_row0_col2" class="data row0 col2" >0.584207</td>
#       <td id="T_2ed88_row0_col3" class="data row0 col3" >0.693147</td>
#       <td id="T_2ed88_row0_col4" class="data row0 col4" >0.693147</td>
#       <td id="T_2ed88_row0_col5" class="data row0 col5" >0.693147</td>
#       <td id="T_2ed88_row0_col6" class="data row0 col6" >0.693147</td>
#       <td id="T_2ed88_row0_col7" class="data row0 col7" >0.693147</td>
#       <td id="T_2ed88_row0_col8" class="data row0 col8" >1.098612</td>
#       <td id="T_2ed88_row0_col9" class="data row0 col9" >1.098612</td>
#       <td id="T_2ed88_row0_col10" class="data row0 col10" >1.386294</td>
#       <td id="T_2ed88_row0_col11" class="data row0 col11" >1.609438</td>
#       <td id="T_2ed88_row0_col12" class="data row0 col12" >1.791759</td>
#       <td id="T_2ed88_row0_col13" class="data row0 col13" >2.079442</td>
#       <td id="T_2ed88_row0_col14" class="data row0 col14" >2.397895</td>
#       <td id="T_2ed88_row0_col15" class="data row0 col15" >3.044522</td>
#       <td id="T_2ed88_row0_col16" class="data row0 col16" >5.303305</td>
#     </tr>
#     <tr>
#       <th id="T_2ed88_level0_row1" class="row_heading level0 row1" >order_num_total_ever_offline</th>
#       <td id="T_2ed88_row1_col0" class="data row1 col0" >19945.000000</td>
#       <td id="T_2ed88_row1_col1" class="data row1 col1" >0.979916</td>
#       <td id="T_2ed88_row1_col2" class="data row1 col2" >0.375796</td>
#       <td id="T_2ed88_row1_col3" class="data row1 col3" >0.693147</td>
#       <td id="T_2ed88_row1_col4" class="data row1 col4" >0.693147</td>
#       <td id="T_2ed88_row1_col5" class="data row1 col5" >0.693147</td>
#       <td id="T_2ed88_row1_col6" class="data row1 col6" >0.693147</td>
#       <td id="T_2ed88_row1_col7" class="data row1 col7" >0.693147</td>
#       <td id="T_2ed88_row1_col8" class="data row1 col8" >0.693147</td>
#       <td id="T_2ed88_row1_col9" class="data row1 col9" >1.098612</td>
#       <td id="T_2ed88_row1_col10" class="data row1 col10" >1.098612</td>
#       <td id="T_2ed88_row1_col11" class="data row1 col11" >1.386294</td>
#       <td id="T_2ed88_row1_col12" class="data row1 col12" >1.386294</td>
#       <td id="T_2ed88_row1_col13" class="data row1 col13" >1.609438</td>
#       <td id="T_2ed88_row1_col14" class="data row1 col14" >1.609438</td>
#       <td id="T_2ed88_row1_col15" class="data row1 col15" >2.079442</td>
#       <td id="T_2ed88_row1_col16" class="data row1 col16" >4.700480</td>
#     </tr>
#     <tr>
#       <th id="T_2ed88_level0_row2" class="row_heading level0 row2" >customer_value_total_ever_offline</th>
#       <td id="T_2ed88_row2_col0" class="data row2 col0" >19945.000000</td>
#       <td id="T_2ed88_row2_col1" class="data row2 col1" >5.179682</td>
#       <td id="T_2ed88_row2_col2" class="data row2 col2" >0.850698</td>
#       <td id="T_2ed88_row2_col3" class="data row2 col3" >2.397895</td>
#       <td id="T_2ed88_row2_col4" class="data row2 col4" >4.110710</td>
#       <td id="T_2ed88_row2_col5" class="data row2 col5" >4.615022</td>
#       <td id="T_2ed88_row2_col6" class="data row2 col6" >4.713845</td>
#       <td id="T_2ed88_row2_col7" class="data row2 col7" >4.950389</td>
#       <td id="T_2ed88_row2_col8" class="data row2 col8" >5.198387</td>
#       <td id="T_2ed88_row2_col9" class="data row2 col9" >5.402047</td>
#       <td id="T_2ed88_row2_col10" class="data row2 col10" >5.644980</td>
#       <td id="T_2ed88_row2_col11" class="data row2 col11" >5.902792</td>
#       <td id="T_2ed88_row2_col12" class="data row2 col12" >6.065867</td>
#       <td id="T_2ed88_row2_col13" class="data row2 col13" >6.255654</td>
#       <td id="T_2ed88_row2_col14" class="data row2 col14" >6.544231</td>
#       <td id="T_2ed88_row2_col15" class="data row2 col15" >7.107382</td>
#       <td id="T_2ed88_row2_co

# %%
# Calculates the lower and upper thresholds to identify outliers for a given column in the dataframe

def outlier_thresholds(dataframe, col_name, q1=0.05, q3=0.95):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit


# Checks if a specific column in the dataframe contains any outliers based on calculated thresholds

def check_outlier(dataframe, col_name):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name] > up_limit) | (dataframe[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False


# Checks all columns in the dataframe for the presence of outliers and returns a dictionary with the results        

def check_all_columns_outliers(dataframe):
    numeric_cols = dataframe.select_dtypes(include=['int64', 'float64']).columns
    results = {}
    for col in numeric_cols:
        results[col] = check_outlier(dataframe, col)
    return results

# %%
outlier_results = check_all_columns_outliers(df)
for col, has_outliers in outlier_results.items():
    print(f"{col}: {'Outliers present' if has_outliers else 'No outliers'}")
# Out:
# order_num_total_ever_online: Outliers present
# order_num_total_ever_offline: Outliers present
# customer_value_total_ever_offline: No outliers
# customer_value_total_ever_online: No outliers

# %%
def replace_with_thresholds(dataframe, variable, q1=0.1, q3=0.90):
    low_limit, up_limit = outlier_thresholds(dataframe, variable, q1, q3)
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit


for col in numeric_cols:
    replace_with_thresholds(df, col)

# %%
plot_boxplot_per_variable(df[numeric_cols])

# %% [markdown]
# <div style="text-align:center; font-size:26px; border: 2px solid #ffffff; border-radius: 5px; padding: 10px; margin-bottom: 10px; background-color:#2c4d80 ; font-family: Roboto ;  color: #ffffff;"> FEATURE EXTRACTION
# </div>

# %%
## Feature1
df["New_Total_Order"] = df["order_num_total_ever_online"] + df["order_num_total_ever_offline"]

## Feature2
df["New_Total_Price"] = df["customer_value_total_ever_online"] + df["customer_value_total_ever_offline"]

## Feature3 - Customer Age
df['first_order_date'] = pd.to_datetime(df['first_order_date'])
df['New_Tenure'] = (pd.Timestamp.now() - df['first_order_date']).dt.days

## Feature4 - order frequency (average_orders_per_day)
df['New_Avg_Orders_Per_Day'] = df["New_Total_Order"] / df['New_Tenure']

## Feature5 - customer_value_difference
df['New_Customer_Value_Difference'] = df['customer_value_total_ever_online'] - df['customer_value_total_ever_offline']

## Feature6 - num_interest_categories
df['New_Num_Interest_Categories'] = df['interested_in_categories_12'].str.split(',').apply(len)

## Feature7- days_since_last_order
df['last_order_date'] = pd.to_datetime(df['last_order_date'])
df['New_Recency'] = (pd.Timestamp.now() - df['last_order_date']).dt.days

# %%
check_df(df)
# Out:
# --------------------------------SHAPE---------------------------------
# (19945, 19)
# ---------------------------------INFO---------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  datetime64[ns]
#  4   last_order_date                    19945 non-null  datetime64[ns]
#  5   last_order_date_online             19945 non-null  datetime64[ns]
#  6   last_order_date_offline            19945 non-null  datetime64[ns]
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
#  11  interested_in_categories_12        19945 non-null  object
#  12  New_Total_Order                    19945 non-null  float64
#  13  New_Total_Price                    19945 non-null  float64
#  14  New_Tenure                         19945 non-null  int64
#  15  New_Avg_Orders_Per_Day             19945 non-null  float64
#  16  New_Customer_Value_Difference      19945 non-null  float64
#  17  New_Num_Interest_Categories        19945 non-null  int64
#  18  New_Recency                        19945 non-null  int64
# dtypes: datetime64[ns](4), float64(8), int64(3), object(4)
# memory usage: 2.9+ MB
# None
# -----------------------------MEMORY USAGE-----------------------------
# 2.89 MB
# -------------------------------NUNIQUE--------------------------------
# master_id                            19945
# order_channel                            4
# last_order_channel                       5
# first_order_date                      2465
# last_order_date                        366
# last_order_date_online                1743
# last_order_date_offline                738
# order_num_total_ever_online             51
# order_num_total_ever_offline            19
# customer_value_total_ever_offline     6097
# customer_value_total_ever_online     11292
# interested_in_categories_12             32
# New_Total_Order                        150
# New_Total_Price                      19354
# New_Tenure                            2465
# New_Avg_Orders_Per_Day                9661
# New_Customer_Value_Difference        19484
# New_Num_Interest_Categories              5
# New_Recency                            366
# dtype: int64
# ----------------------------MISSING VALUES----------------------------
# master_id                            0
# order_channel                        0
# last_order_channel                   0
# first_order_date                     0
# last_order_date                      0
# last_order_date_online               0
# last_order_date_offline              0
# order_num_total_ever_online          0
# order_num_total_ever_offline         0
# customer_value_total_ever_offline    0
# customer_value_total_ever_online     0
# interested_in_categories_12          0
# New_Total_Order                      0
# New_Total_Price                      0
# New_Tenure                           0
# New_Avg_Orders_Per_Day               0
# New_Customer_Value_Difference        0
# New_Num_Interest_Categories          0
# New_Recency                          0
# dtype: int64
# --------------------------DUPLICATED VALUES---------------------------
# 0

# %% [markdown]
# <div style="text-align:center; font-size:26px; border: 2px solid #ffffff; border-radius: 5px; padding: 10px; margin-bottom: 10px; background-color:#2c4d80 ; font-family: Roboto ;  color: #ffffff;"> K-Means Clustering
# </div>

# %%
def one_hot_encoder(dataframe, categorical_cols, drop_first=True):
    dataframe = pd.get_dummies(dataframe, columns=categorical_cols, drop_first=drop_first)
    dataframe = dataframe.applymap(lambda x: 1 if x is True else (0 if x is False else x))
    return dataframe

df = one_hot_encoder(df, cat_cols, drop_first=True)

# %%
## refrain
cat_cols, num_cols, num_but_cat, cat_but_car = grab_col_names(df)

print(num_cols)
# Out:
# Observations: 19945
# Variables: 24
# cat_cols: 8
# num_cols: 14
# cat_but_car: 2
# num_but_cat: 8
# ['first_order_date', 'last_order_date', 'last_order_date_online', 'last_order_date_offline', 'order_num_total_ever_online', 'order_num_total_ever_offline', 'customer_value_total_ever_offline', 'customer_value_total_ever_online', 'New_Total_Order', 'New_Total_Price', 'New_Tenure', 'New_Avg_Orders_Per_Day', 'New_Customer_Value_Difference', 'New_Recency']

# %%
df.head()
# Out:
#                               master_id first_order_date last_order_date last_order_date_online last_order_date_offline  order_num_total_ever_online  order_num_total_ever_offline  customer_value_total_ever_offline  customer_value_total_ever_online       interested_in_categories_12  New_Total_Order  New_Total_Price  New_Tenure  New_Avg_Orders_Per_Day  New_Customer_Value_Difference  New_Num_Interest_Categories  New_Recency  order_channel_Desktop  order_channel_Ios App  order_channel_Mobile  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f       2020-10-30      2021-02-26             2021-02-21              2021-02-26                        1.609                         0.693                              4.949                             6.685                           [KADIN]            2.303           11.634        1355                   0.002                          1.736                            1         1236                      0                      0                     0
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f       2017-02-08      2021-02-16             2021-02-16              2020-01-10                        2.996                         1.099                              5.081                             7.525  [ERKEK, COCUK, KADIN, AKTIFSPOR]            4.094           12.607        2715                   0.002                          2.444                            4         1246                      0                      0                     0
# 2  69b69676-1a40-11ea-941b-000d3a38a36f       2019-11-27      2020-11-27             2020-11-27              2019-12-01                        1.386                         1.099                              5.252                             5.982                    [ERKEK, KADIN]            2.485           11.234        1693                   0.001                          0.730                            2         1327                      0                      0                     0
# 3  1854e56c-491f-11eb-806e-000d3a38a36f       2021-01-06      2021-01-17             2021-01-17              2021-01-06                        0.693                         0.693                              3.713                             4.419               [AKTIFCOCUK, COCUK]            1.386            8.132        1287                   0.001                          0.705                            2         1276                      0                      0                     0
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       2019-08-03      2021-03-07             2021-03-07              2019-08-03                        0.693                         0.693                              3.932                             5.081                       [AKTIFSPOR]            1.386            9.013        1809                   0.001                          1.150                            1         1227                      1                      0                     0
#
#    last_order_channel_Desktop  last_order_channel_Ios App  last_order_channel_Mobile  last_order_channel_Offline
# 0                           0                           0                          0                           1
# 1                           0                           0                          1                           0
# 2                           0                           0                          0                           0
# 3                           0                           0                          0                           0
# 4                           1                           0                          0                           0

# %%
scaler = StandardScaler()

scales = [
'order_num_total_ever_online', 'order_num_total_ever_offline',
'customer_value_total_ever_offline', 'customer_value_total_ever_online',
'New_Total_Order', 'New_Total_Price', 'New_Tenure', 'New_Avg_Orders_Per_Day',
'New_Customer_Value_Difference', 'New_Recency',
'order_channel_Desktop', 'order_channel_Ios App', 'order_channel_Mobile',
'last_order_channel_Desktop', 'last_order_channel_Ios App',
'last_order_channel_Mobile', 'last_order_channel_Offline'
]


df_scaled = scaler.fit_transform(df[scales])
df_scaled = pd.DataFrame(df_scaled, columns=scales)

# %%
df_scaled.head()
# Out:
#    order_num_total_ever_online  order_num_total_ever_offline  customer_value_total_ever_offline  customer_value_total_ever_online  New_Total_Order  New_Total_Price  New_Tenure  New_Avg_Orders_Per_Day  New_Customer_Value_Difference  New_Recency  order_channel_Desktop  order_channel_Ios App  order_channel_Mobile  last_order_channel_Desktop  last_order_channel_Ios App  last_order_channel_Mobile  last_order_channel_Offline
# 0                        0.714                        -0.771                             -0.272                             1.010            0.186            0.576      -1.122                   1.574                          0.949       -0.382                 -0.399                 -0.407                -0.569                      -0.304                      -0.305                     -0.435                       1.421
# 1                        3.090                         0.322                             -0.116                             1.873            2.737            1.321       1.476                   1.027                          1.502       -0.285                 -0.399                 -0.407                -0.569                      -0.304                      -0.305                      2.300                      -0.704
# 2                        0.332                         0.322                              0.085                             0.288            0.446            0.270      -0.476                   0.912                          0.162        0.499                 -0.399                 -0.407                -0.569                      -0.304                      -0.305                     -0.435                      -0.704
# 3                       -0.856                        -0.771                             -1.724                            -1.318           -1.119           -2.106      -1.252                  -0.205                          0.143        0.005                 -0.399                 -0.407                -0.569                      -0.304                      -0.305                     -0.435                      -0.704
# 4                       -0.856                        -0.771                             -1.467                            -0.638           -1.119           -1.431      -0.255                  -1.094                          0.490       -0.469                  2.508                 -0.407                -0.569                       3.291                      -0.305                     -0.435                      -0.704

# %%
# Optimal number of clusters using the Elbow method
inertia = []
ssd = []
for k in range(1, 40):
    kmeans = KMeans(n_clusters=k, random_state=52)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)
    ssd.append(kmeans.inertia_)

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(range(1, 40), ssd, marker='o', linestyle='-', color='r', markerfacecolor='b')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Sum of Squared Distances (Inertia)')
plt.title('K-Means Performance Metrics with SSE/SSR/SSD')
plt.axvline(x=10, color='r', linestyle='--')
plt.xticks(range(1, 40))
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
plt.tight_layout()
plt.show();

# %%
elbow = KElbowVisualizer(kmeans, k=(1, 40)).fit(df_scaled)

plt.figure(figsize=(10, 6))
elbow.show();

# %%
kmeans = KMeans(n_clusters=elbow.elbow_value_).fit(df_scaled)

clusters_kmeans = kmeans.labels_

# %%
df["cluster"] = clusters_kmeans
df["cluster"] = df["cluster"] + 1

# %%
df.head()
# Out:
#                               master_id first_order_date last_order_date last_order_date_online last_order_date_offline  order_num_total_ever_online  order_num_total_ever_offline  customer_value_total_ever_offline  customer_value_total_ever_online       interested_in_categories_12  New_Total_Order  New_Total_Price  New_Tenure  New_Avg_Orders_Per_Day  New_Customer_Value_Difference  New_Num_Interest_Categories  New_Recency  order_channel_Desktop  order_channel_Ios App  order_channel_Mobile  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f       2020-10-30      2021-02-26             2021-02-21              2021-02-26                        1.609                         0.693                              4.949                             6.685                           [KADIN]            2.303           11.634        1355                   0.002                          1.736                            1         1236                      0                      0                     0
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f       2017-02-08      2021-02-16             2021-02-16              2020-01-10                        2.996                         1.099                              5.081                             7.525  [ERKEK, COCUK, KADIN, AKTIFSPOR]            4.094           12.607        2715                   0.002                          2.444                            4         1246                      0                      0                     0
# 2  69b69676-1a40-11ea-941b-000d3a38a36f       2019-11-27      2020-11-27             2020-11-27              2019-12-01                        1.386                         1.099                              5.252                             5.982                    [ERKEK, KADIN]            2.485           11.234        1693                   0.001                          0.730                            2         1327                      0                      0                     0
# 3  1854e56c-491f-11eb-806e-000d3a38a36f       2021-01-06      2021-01-17             2021-01-17              2021-01-06                        0.693                         0.693                              3.713                             4.419               [AKTIFCOCUK, COCUK]            1.386            8.132        1287                   0.001                          0.705                            2         1276                      0                      0                     0
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       2019-08-03      2021-03-07             2021-03-07              2019-08-03                        0.693                         0.693                              3.932                             5.081                       [AKTIFSPOR]            1.386            9.013        1809                   0.001                          1.150                            1         1227                      1                      0                     0
#
#    last_order_channel_Desktop  last_order_channel_Ios App  last_order_channel_Mobile  last_order_channel_Offline  cluster
# 0                           0                           0                          0                           1        2
# 1                           0                           0                          1                           0        5
# 2                           0                           0                          0                           0        2
# 3                           0                           0                          0                           0        3
# 4                           1                           0                          0                           0        7

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
cluster_stats = df.groupby("cluster")[numeric_cols].agg(["mean", "median", "count", "sum"]).T

# Define a function to highlight the maximum value in each column
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: red' if v else '' for v in is_max]


cluster_stats.style.apply(highlight_max, axis=1)
# Out:
# <style type="text/css">
# #T_aa13c_row0_col4, #T_aa13c_row1_col4, #T_aa13c_row2_col2, #T_aa13c_row3_col1, #T_aa13c_row4_col7, #T_aa13c_row5_col7, #T_aa13c_row5_col9, #T_aa13c_row6_col2, #T_aa13c_row7_col7, #T_aa13c_row8_col7, #T_aa13c_row9_col7, #T_aa13c_row10_col2, #T_aa13c_row11_col7, #T_aa13c_row12_col4, #T_aa13c_row13_col4, #T_aa13c_row14_col2, #T_aa13c_row15_col1, #T_aa13c_row16_col9, #T_aa13c_row17_col9, #T_aa13c_row18_col2, #T_aa13c_row19_col1, #T_aa13c_row20_col9, #T_aa13c_row21_col9, #T_aa13c_row22_col2, #T_aa13c_row23_col1, #T_aa13c_row24_col4, #T_aa13c_row25_col4, #T_aa13c_row26_col2, #T_aa13c_row27_col2, #T_aa13c_row28_col9, #T_aa13c_row29_col9, #T_aa13c_row30_col2, #T_aa13c_row31_col1, #T_aa13c_row32_col4, #T_aa13c_row33_col4, #T_aa13c_row34_col2, #T_aa13c_row35_col1, #T_aa13c_row36_col9, #T_aa13c_row37_col1, #T_aa13c_row37_col4, #T_aa13c_row37_col7, #T_aa13c_row37_col9, #T_aa13c_row38_col2, #T_aa13c_row39_col1, #T_aa13c_row40_col8, #T_aa13c_row41_col8, #T_aa13c_row42_col2, #T_aa13c_row43_col2, #T_aa13c_row44_col8, #T_aa13c_row45_col6, #T_aa13c_row45_col8, #T_aa13c_row46_col2, #T_aa13c_row47_col8, #T_aa13c_row48_col5, #T_aa13c_row49_col5, #T_aa13c_row50_col2, #T_aa13c_row51_col5, #T_aa13c_row52_col3, #T_aa13c_row53_col3, #T_aa13c_row54_col2, #T_aa13c_row55_col3, #T_aa13c_row56_col6, #T_aa13c_row57_col6, #T_aa13c_row58_col2, #T_aa13c_row59_col6, #T_aa13c_row60_col5, #T_aa13c_row61_col5, #T_aa13c_row62_col2, #T_aa13c_row63_col5, #T_aa13c_row64_col3, #T_aa13c_row65_col3, #T_aa13c_row66_col2, #T_aa13c_row67_col3, #T_aa13c_row68_col0, #T_aa13c_row68_col8, #T_aa13c_row69_col0, #T_aa13c_row69_col7, #T_aa13c_row69_col8, #T_aa13c_row70_col2, #T_aa13c_row71_col0, #T_aa13c_row72_col9, #T_aa13c_row73_col9, #T_aa13c_row74_col2, #T_aa13c_row75_col7 {
#   background-color: red;
# }
# </style>
# <table id="T_aa13c">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >cluster</th>
#       <th id="T_aa13c_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_aa13c_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_aa13c_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_aa13c_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_aa13c_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_aa13c_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_aa13c_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_aa13c_level0_col7" class="col_heading level0 col7" >8</th>
#       <th id="T_aa13c_level0_col8" class="col_heading level0 col8" >9</th>
#       <th id="T_aa13c_level0_col9" class="col_heading level0 col9" >10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa13c_level0_row0" class="row_heading level0 row0" rowspan="4">order_num_total_ever_online</th>
#       <th id="T_aa13c_level1_row0" class="row_heading level1 row0" >mean</th>
#       <td id="T_aa13c_row0_col0" class="data row0 col0" >0.824986</td>
#       <td id="T_aa13c_row0_col1" class="data row0 col1" >1.648094</td>
#       <td id="T_aa13c_row0_col2" class="data row0 col2" >0.840889</td>
#       <td id="T_aa13c_row0_col3" class="data row0 col3" >0.944131</td>
#       <td id="T_aa13c_row0_col4" class="data row0 col4" >2.328496</td>
#       <td id="T_aa13c_row0_col5" class="data row0 col5" >1.199816</td>
#       <td id="T_aa13c_row0_col6" class="data row0 col6" >1.060071</td>
#       <td id="T_aa13c_row0_col7" class="data row0 col7" >0.972690</td>
#       <td id="T_aa13c_row0_col8" class="data row0 col8" >0.864844</td>
#       <td id="T_aa13c_row0_col9" class="data row0 col9" >2.068177</td>
#     </tr>
#     <tr>
#       <th id="T_aa13c_level1_row1" class="row_heading level1 row1" >median</th>
#       <td id="T_aa13c_row1_col0" class="data row1 col0" >0.693147</td>
#       <td id="T_aa13c_row1_col1" class="data row1 col1" >1.609438</td>
#       <td id="T_aa13c_row1_col2" class="data row1 col2" >0.693147</td>
#       <td id="T_aa13c_row1_col3" class="data row1 col3" >0.693147</td>
#       <td id="T_aa13c_row1_col4" class="data row1 col4" >2.302585</td>
#       <td id="T_aa13c_row1_col5" class="data row1 col5" >1.098612</td>
#       <td id="T_aa13c_row1_col6" class="data row1 col6" >1.098612</td>
#       <td id="T_aa13c_row1_col7" class="data row1 col7" >1.098612</td>
#       <td id="T_aa13c_row1_col8" class="data row1 col8" >0.693147</td>
#       <td id="T_aa13c_row1_col9" class="data row1 col9" >1.945910</td>
#     </tr>
#     <tr>
#       <th id="T_aa13c_level1_row2" class="row_heading level1 row2" >count</th>
#       <td id="T_aa13c_row2_col0" class="data row2 col0" >2556.000000</td>
#       <td id="T_aa13c_row2_col1" class="data row2 col1" >2593.000000</td>
#       <td id="T_aa13c_row2_col2" class="data row2 col2" >2885.000000</td>
#       <td id="T_aa13c_row2_col3" class="data row2 col3" >2541.000000</td>
#       <td id="T_aa13c_row2_col4" class="data row2 col4" >1175.000000</td>
#       <td id="T_aa13c_row2_col5" class="data row2 col5" >1619.000000</td>
#       <td id="T_aa13c_row2_col6" class="data row2 col6" >1379.000000</td>
#       <td id="T_aa13c_row2_col7" class="data row2 col7" >2406.000000</td>
#       <td id="T_aa13c_row2_col8" class="data row2 col8" >1390.000000</td>
#       <td id="T_aa13c_row2_col9" class="data row2 col9" >1401.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aa13c_level1_row3" class="row_heading level1 row3" >sum</th>
#       <td id="T_aa13c_row3_col0" class="data row3 col0" >2108.663915</td>
#       <td id="T_aa13c_row3_col1" class="data row3 col1" >4273.507399</td>
#       <td id="T_aa13c_row3_col2" class="data row3 col2" >2425.963841</td>
#       <td id="T_aa13c_row3_col3" class="data row3 col3" >2399.037535</td>
#       <td id="T_aa13c_row3_col4" class="data row3 col4" >2735.983151</td>
#       <td id="T_aa13c_row3_col5" class="data row3 col5" >1942.501767</td>
#       <td id="T_aa13c_row3_col6" class="data row3 col6" >1461.838081</td>
#       <td id="T_aa13c_row3_col7" class="data row3 col7" >2340.292478</td>
#       <td id="T_aa13c_row3_col8" class="data row3 col8" >1202.132541</td>
#       <td id="T_aa13c_row3_col9" class="data row3 col9" >2897.516393</td>
#     </tr>
#     <tr>
#       <th id="T_aa13c_level0_row4" class="row_heading level0 row4" rowspan="4">order_num_total_ever_offline</th>
#       <th id="T_aa13c_level1_row4" class="row_heading level1 row4" >mean</th>
#       <td id="T_aa13c_row4_col0" class="data row4 col0" >0.859781</td>
#       <td id="T_aa13c_row4_col1" class="data row4 col1" >0.803658</td>
#       <td id="T_aa13c_row4_col2" class="data row4 col2" >0.799156</td>
#       <td id="T_aa13c_row4_col3" class="data row4 col3" >0.861000</td>
#       <td id="T_aa13c_row4_col4" class="data row4 col4" >0.898395</td>
#       <td id="T_aa13c_row4_col5" class="data row4 col5" >0.892080</td>
#       <td id="T_aa13c_row4_col6" class="data row4 col6" >0.875869</td>
#       <td id="T_aa13c_row4_col7" class="data row4 col7" >1.504872</td>
#       <td id="T_aa13c_row4_col8" class="data row4 col8" >1.002219</td>
#       <td id="T_aa13c_row4_col9" class="data row4 col9" >1.452232</td>
#     </tr>
#     <tr>
#       <th id="T_aa13c_level1_row5" class="row_heading level1 row5" >median</th>
#       <td id="T_aa13c_row5_col0" class="data row5 col0" >0.693147</td>
#       <td id="T_aa13c_row5_col1" class="data row5 col1" >0.693147</td>
#       <td id="T_aa13c_row5_col2" class="data row5 col2" >0.693147</td>
#       <td id="T_aa13c_row5_col3" class="data row5 col3" >0.693147</td>
#       <td id="T_aa13c_row5_col4" class="data row5 col4" >0.693147</td>
#       <td id="T_aa13c_row5_col5" class="data row5 col5" >0.693147</td>
#       <td id="T_aa13c_row5_col6" class="data row5 col6" >0.693147</td>
#       <td id="T_aa13c_row5_col7" class="data row5 col7" >1.386294</td>
#       <td id="T_aa13c_row5_col8" class="data row5 col8" >1.098612</td>
#       <td id="T_aa13c_row5_col9" class="data row5 col9" >1.386294</td>
#     </tr>
#     <tr>
#       <th id="T_aa13c_level1_row6" class="row_heading level1 row6" >count</th>
#       <td id="T_aa13c_row6_col0" class="data row6 col0" >2

# %% [markdown]
# <div style="background-color:#B0C4A4; border-radius: 10px; padding: 10px; margin-bottom: 20px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#         <p style="margin: 10px 0 0 0; font-size: 22px; font-weight: Bold; font-family: Roboto; color: #1F2A44; text-align: center;">📝 Comments</p>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">order_num_total_ever_online: Cluster 3 has the highest mean value (2.33), but Cluster 7 has the highest median value (1.95). This suggests that Cluster 3 generally has higher values, but the distribution might be widely spread.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">order_num_total_ever_offline: Cluster 10 shows the highest total value for this feature (3619.81). This indicates that this cluster engages more in offline transactions.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">customer_value_total_ever_offline: Cluster 7 has the highest mean value (6.04) in total customer value. On the other hand, Cluster 4 has the highest median value (5.08). This suggests that Cluster 7 interacts more with higher-value customers.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">New_Total_Order: Cluster 7 exhibits the highest mean value (3.52) for new total orders. This indicates that this cluster receives more orders, distinguishing it from others in this aspect.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">order_channel_Desktop, order_channel_Ios App, order_channel_Mobile: Different clusters show varying usage rates for each channel. For instance, Cluster 2 has a 100% usage rate for Ios App, while Cluster 7 shows a high usage rate for Desktop.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">New_Recency: Cluster 1 has the lowest median value (1293). This suggests that this cluster has engaged more recently in transactions or interactions.</p>
#     </div>
# </div>

# %%
# Calculate the number of observations in each cluster
cluster_counts = df["cluster"].value_counts().sort_index()

# Choose a color palette
colors = plt.cm.get_cmap('viridis', len(cluster_counts))

# Create the bar plot
plt.figure(figsize=(12, 8))
bars = plt.bar(cluster_counts.index, cluster_counts.values, color=colors(range(len(cluster_counts))))

# Axis labels and title
plt.xlabel('Cluster', fontsize=14)
plt.ylabel('Number of Customers', fontsize=14)
plt.title('Cluster Distribution', fontsize=16)
plt.xticks(cluster_counts.index)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add cluster numbers and observation counts on top of each bar
for bar, count in zip(bars, cluster_counts.values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 20, f'{count}', ha='center', va='bottom', fontsize=10)

# Color bar and labels
sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=min(cluster_counts.index), vmax=max(cluster_counts.index)))
sm._A = []
cbar = plt.colorbar(sm)
cbar.set_label('Cluster', rotation=270, labelpad=15)

plt.tight_layout()
plt.show();

# %% [markdown]
# <div style="text-align:center; font-size:26px; border: 2px solid #ffffff; border-radius: 5px; padding: 10px; margin-bottom: 10px; background-color:#2c4d80 ; font-family: Roboto ;  color: #ffffff;"> Hierarchical Clustering
# </div>

# %%
linkage_matrix = linkage(df_scaled, method='ward', metric='euclidean')

# Dendrogram
plt.figure(figsize=(10, 8))
dendrogram(linkage_matrix,
           truncate_mode='lastp', 
           p=30,                   
           show_leaf_counts=True,  
           leaf_rotation=90.,     
           leaf_font_size=12.,   
           show_contracted=True)  

# Labels, title, and axes
plt.title('Hierarchical Clustering Dendrogram', fontsize=12)
plt.xlabel('Observations', fontsize=10)
plt.ylabel('Distance', fontsize=10)

# Adding cut-off lines
plt.axhline(y=200, color='r', linestyle='--', linewidth=2, label='Cut-off Line 1')
plt.axhline(y=180, color='b', linestyle='--', linewidth=2, label='Cut-off Line 2')

# Displaying the legend
plt.legend(loc='upper right')
plt.show();

# %%
cluster = AgglomerativeClustering(n_clusters=6, linkage="ward")
cluster = cluster.fit_predict(df_scaled)

# %%
df["hi_cluster_no"] = cluster
df["hi_cluster_no"] = df["hi_cluster_no"] + 1

# %%
# Function definition to plot cluster distribution with annotations
def plot_cluster_distribution(dataframe, col_name):
    plt.figure(figsize=(10, 6))
    sns.countplot(x=dataframe[col_name], data=dataframe)
    plt.title('Cluster Distribution')
    plt.xlabel('Cluster')
    plt.ylabel('Number of Observations')

    # Calculate ratio and annotate each bar
    total = len(dataframe)
    for p in plt.gca().patches:
        height = p.get_height()
        plt.gca().annotate(f'{height / total * 100:.2f}%', 
                           (p.get_x() + p.get_width() / 2., height), 
                           ha='center', va='bottom', fontsize=10, color='black')

    plt.show()


plot_cluster_distribution(df, "hi_cluster_no")

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
cluster_stats = df.groupby("hi_cluster_no")[numeric_cols].agg(["mean", "median", "count", "sum"]).T

# Define a function to highlight the maximum value in each column
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: purple' if v else '' for v in is_max]


cluster_stats.style.apply(highlight_max, axis=1)
# Out:
# <style type="text/css">
# #T_fac6f_row0_col1, #T_fac6f_row1_col1, #T_fac6f_row2_col2, #T_fac6f_row3_col1, #T_fac6f_row4_col0, #T_fac6f_row5_col0, #T_fac6f_row5_col1, #T_fac6f_row6_col2, #T_fac6f_row7_col0, #T_fac6f_row8_col0, #T_fac6f_row9_col0, #T_fac6f_row10_col2, #T_fac6f_row11_col0, #T_fac6f_row12_col1, #T_fac6f_row13_col1, #T_fac6f_row14_col2, #T_fac6f_row15_col1, #T_fac6f_row16_col1, #T_fac6f_row17_col1, #T_fac6f_row18_col2, #T_fac6f_row19_col1, #T_fac6f_row20_col1, #T_fac6f_row21_col1, #T_fac6f_row22_col2, #T_fac6f_row23_col0, #T_fac6f_row24_col0, #T_fac6f_row25_col0, #T_fac6f_row26_col2, #T_fac6f_row27_col0, #T_fac6f_row28_col1, #T_fac6f_row29_col1, #T_fac6f_row30_col2, #T_fac6f_row31_col1, #T_fac6f_row32_col1, #T_fac6f_row33_col1, #T_fac6f_row34_col2, #T_fac6f_row35_col1, #T_fac6f_row36_col1, #T_fac6f_row37_col1, #T_fac6f_row38_col2, #T_fac6f_row39_col1, #T_fac6f_row40_col2, #T_fac6f_row41_col2, #T_fac6f_row42_col2, #T_fac6f_row43_col2, #T_fac6f_row44_col4, #T_fac6f_row45_col4, #T_fac6f_row46_col2, #T_fac6f_row47_col0, #T_fac6f_row48_col5, #T_fac6f_row49_col5, #T_fac6f_row50_col2, #T_fac6f_row51_col5, #T_fac6f_row52_col3, #T_fac6f_row53_col3, #T_fac6f_row54_col2, #T_fac6f_row55_col3, #T_fac6f_row56_col4, #T_fac6f_row57_col4, #T_fac6f_row58_col2, #T_fac6f_row59_col4, #T_fac6f_row60_col5, #T_fac6f_row61_col5, #T_fac6f_row62_col2, #T_fac6f_row63_col5, #T_fac6f_row64_col3, #T_fac6f_row65_col3, #T_fac6f_row66_col2, #T_fac6f_row67_col3, #T_fac6f_row68_col0, #T_fac6f_row69_col0, #T_fac6f_row70_col2, #T_fac6f_row71_col0, #T_fac6f_row72_col4, #T_fac6f_row73_col0, #T_fac6f_row74_col2, #T_fac6f_row75_col0, #T_fac6f_row76_col5, #T_fac6f_row77_col5, #T_fac6f_row78_col2, #T_fac6f_row79_col2 {
#   background-color: purple;
# }
# </style>
# <table id="T_fac6f">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >hi_cluster_no</th>
#       <th id="T_fac6f_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_fac6f_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_fac6f_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_fac6f_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_fac6f_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_fac6f_level0_col5" class="col_heading level0 col5" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fac6f_level0_row0" class="row_heading level0 row0" rowspan="4">order_num_total_ever_online</th>
#       <th id="T_fac6f_level1_row0" class="row_heading level1 row0" >mean</th>
#       <td id="T_fac6f_row0_col0" class="data row0 col0" >0.998373</td>
#       <td id="T_fac6f_row0_col1" class="data row0 col1" >1.823770</td>
#       <td id="T_fac6f_row0_col2" class="data row0 col2" >0.879862</td>
#       <td id="T_fac6f_row0_col3" class="data row0 col3" >1.062235</td>
#       <td id="T_fac6f_row0_col4" class="data row0 col4" >1.288238</td>
#       <td id="T_fac6f_row0_col5" class="data row0 col5" >1.260568</td>
#     </tr>
#     <tr>
#       <th id="T_fac6f_level1_row1" class="row_heading level1 row1" >median</th>
#       <td id="T_fac6f_row1_col0" class="data row1 col0" >0.693147</td>
#       <td id="T_fac6f_row1_col1" class="data row1 col1" >1.791759</td>
#       <td id="T_fac6f_row1_col2" class="data row1 col2" >0.693147</td>
#       <td id="T_fac6f_row1_col3" class="data row1 col3" >0.693147</td>
#       <td id="T_fac6f_row1_col4" class="data row1 col4" >1.098612</td>
#       <td id="T_fac6f_row1_col5" class="data row1 col5" >1.098612</td>
#     </tr>
#     <tr>
#       <th id="T_fac6f_level1_row2" class="row_heading level1 row2" >count</th>
#       <td id="T_fac6f_row2_col0" class="data row2 col0" >4704.000000</td>
#       <td id="T_fac6f_row2_col1" class="data row2 col1" >4031.000000</td>
#       <td id="T_fac6f_row2_col2" class="data row2 col2" >4851.000000</td>
#       <td id="T_fac6f_row2_col3" class="data row2 col3" >2981.000000</td>
#       <td id="T_fac6f_row2_col4" class="data row2 col4" >1682.000000</td>
#       <td id="T_fac6f_row2_col5" class="data row2 col5" >1696.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fac6f_level1_row3" class="row_heading level1 row3" >sum</th>
#       <td id="T_fac6f_row3_col0" class="data row3 col0" >4696.345975</td>
#       <td id="T_fac6f_row3_col1" class="data row3 col1" >7351.615589</td>
#       <td id="T_fac6f_row3_col2" class="data row3 col2" >4268.212813</td>
#       <td id="T_fac6f_row3_col3" class="data row3 col3" >3166.523293</td>
#       <td id="T_fac6f_row3_col4" class="data row3 col4" >2166.816873</td>
#       <td id="T_fac6f_row3_col5" class="data row3 col5" >2137.922558</td>
#     </tr>
#     <tr>
#       <th id="T_fac6f_level0_row4" class="row_heading level0 row4" rowspan="4">order_num_total_ever_offline</th>
#       <th id="T_fac6f_level1_row4" class="row_heading level1 row4" >mean</th>
#       <td id="T_fac6f_row4_col0" class="data row4 col0" >1.175631</td>
#       <td id="T_fac6f_row4_col1" class="data row4 col1" >1.068797</td>
#       <td id="T_fac6f_row4_col2" class="data row4 col2" >0.809151</td>
#       <td id="T_fac6f_row4_col3" class="data row4 col3" >0.898168</td>
#       <td id="T_fac6f_row4_col4" class="data row4 col4" >0.912856</td>
#       <td id="T_fac6f_row4_col5" class="data row4 col5" >0.916514</td>
#     </tr>
#     <tr>
#       <th id="T_fac6f_level1_row5" class="row_heading level1 row5" >median</th>
#       <td id="T_fac6f_row5_col0" class="data row5 col0" >1.098612</td>
#       <td id="T_fac6f_row5_col1" class="data row5 col1" >1.098612</td>
#       <td id="T_fac6f_row5_col2" class="data row5 col2" >0.693147</td>
#       <td id="T_fac6f_row5_col3" class="data row5 col3" >0.693147</td>
#       <td id="T_fac6f_row5_col4" class="data row5 col4" >0.693147</td>
#       <td id="T_fac6f_row5_col5" class="data row5 col5" >0.693147</td>
#     </tr>
#     <tr>
#       <th id="T_fac6f_level1_row6" class="row_heading level1 row6" >count</th>
#       <td id="T_fac6f_row6_col0" class="data row6 col0" >4704.000000</td>
#       <td id="T_fac6f_row6_col1" class="data row6 col1" >4031.000000</td>
#       <td id="T_fac6f_row6_col2" class="data row6 col2" >4851.000000</td>
#       <td id="T_fac6f_row6_col3" class="data row6 col3" >2981.000000</td>
#       <td id="T_fac6f_row6_col4" class="data row6 col4" >1682.000000</td>
#       <td id="T_fac6f_row6_col5" class="data row6 col5" >1696.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fac6f_level1_row7" class="row_heading level1 row7" >sum</th>
#       <td id="T_fac6f_row7_col0" class="data row7 col0" >5530.169724</td>
#       <td id="T_fac6f_row7_col1" class="data row7 col1" >4308.321519</td>
#       <td id="T_fac6f_row7_col2" class="data row7 col2" >3925.192951</td>
#       <td id="T_fac6f_row7_col3" class="data row7 col3" >2677.438474</td>
#       <td id="T_fac6f_row7_col4" class="data row7 col4" >1535.423103</td>
#       <td id="T_fac6f_row7_col5" class="data row7 col5" >1554.407551</td>
#     </tr>
#     <tr>
#       <th id="T_fac6f_level0_row8" class="row_heading level0 row8" rowspan="4">customer_value_total_ever_offline</th>
#       <th id="T_fac6f_level1_row8" class="row_heading level1 row8" >mean</th>
#       <td id="T_fac6f_row8_col0" class="data row8 col0" >5.639931</td>
#       <td id="T_fac6f_row8_col1" class="data row8 col1" >5.324751</td>
#       <td id="T_fac6f_row8_col2" class="data row8 col2" >4.800201</td>
#       <td id="T_fac6f_row8_col3" class="data row8 col3" >4.996158</td>
#       <td id="T_fac6f_row8_col4" class="data row8 col4" >5.055131</td>
#       <td id="T_fac6f_row8_col5" class="data row8 col5" >5.089664</td>
#     </tr>
#     <tr>
#       <th id="T_fac6f_level1_row9" class="row_heading level1 row9" >median</th>
#       <td id="T_fac6f_row9_col0" class="data row9 col0" >5.693597</td>
#       <td id="T_fac6f_row9_col1" class="data row9 col1" >5.356445</td>
#       <td id="T_fac6f_row9_col2" class="data row9 col2" >4.795708</td>
#       <td id="T_fac6f_row9_col3" class="data row9 col3" >4.997077</td>
#       <td id="T_fac6f_row9_col4" class="data row9 col4" >5.020421</td>
#       <td id="T_fac6f_row9_col5" class="data row9 col5" >5.081

# %% [markdown]
# <div style="background-color:#B0C4A4; border-radius: 10px; padding: 10px; margin-bottom: 20px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#         <p style="margin: 10px 0 0 0; font-size: 22px; font-weight: Bold; font-family: Roboto; color: #1F2A44; text-align: center;">📝 Comments</p>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">There are significant differences in online and offline order numbers in the table. For example, "hi_cluster_no" 2 has the highest online and offline order numbers (7351 and 4308, respectively). Median values are generally low but vary between clusters.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">There are notable differences between clusters in terms of customer value. For instance, "hi_cluster_no" 2 and 3 rank highest in both online and offline customer value.
# </p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">There are similarities and differences between clusters in terms of total orders and spending. For example, "hi_cluster_no" 2 has the highest total order and spending values.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">There is variability between clusters in terms of customer tenure and average daily order counts. For instance, "hi_cluster_no" 1 has the highest daily average order count, while "hi_cluster_no" 4 has the longest customer tenure.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">There are differences between clusters in terms of new customer value difference and number of interest categories. For example, "hi_cluster_no" 2 has the highest new customer value difference.</p>
#     </div>
#     <div style="border-left: 5px solid #1F2A44; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #333333; text-align: left;">There are variations between clusters in terms of last order recency and order channel preferences. For example, "hi_cluster_no" 4 is distinct from other clusters in terms of last order recency.</p>
#     </div>
# </div>

# %% [markdown]
# <div style="background-color:#6ca0d0; border-radius: 10px; padding: 10px; margin-bottom: 20px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#         <p style="margin: 10px 0 0 0; font-size: 22px; font-weight: Bold; font-family: Roboto; color: #1F2A44; text-align: center;"> RESULT</p>
#     <div style="border-left: 5px solid #ffffff; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #000000; text-align: left;">Clustering analysis was conducted to identify customer segments and understand their shopping behaviors. This enabled uncovering preferences, purchasing patterns, and evaluation criteria among different groups.</p>
#     </div>
#     <div style="border-left: 5px solid #ffffff; padding-left: 15px;">
#         <p style="margin: 10px 0 0 0; font-size: 18px; font-weight: Bold; font-family: Roboto; color: #000000; text-align: left;">These insights will guide targeted and effective marketing strategies to enhance customer satisfaction and optimize revenues.</p>
#     </div>
# </div>

# %% [markdown]
# <div style="background-color: #FFA500; border-radius: 10px; padding: 3px; margin-bottom: 6px; text-align: right;">
#         <p style="margin: 0; font-size: 20px; text-align: center; font-family: 'Arial', sans-serif; font-weight: bold; letter-spacing: 1px; color: black;">🌟 Thank you for taking the time to review my project. Your feedback and comments are extremely valuable for improving my projects.</p>
# <p style="margin: 0; font-size: 12px; text-align: center; font-family: 'Arial', sans-serif; font-weight: bold; letter-spacing: 1px; color: black;"> Please feel free to share your thoughts and suggestions with me 💬</p>
# </div>
